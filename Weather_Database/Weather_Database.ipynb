# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloudiness = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max_Temp': max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_cloudiness,
                         'Wind_Speed': city_wind,
                         'Country': city_country,
                         'Weather_Description': weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | san martin
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | nerchinskiy zavod
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | vardo
# Processing Record 10 of Set 1 | tabou
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | saiha
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | kanye
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | sal rei
# Processing Record 20 of Set 1 | axim
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | tuatapere
# Processing Record 23 of Set 1 | pangody
# Processing Record 24 of Set 1 | hervey bay
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | silvania
# Processing Record 27 of Set 1 | talcahuano
# Processing Record 28 of Set 1 | fuerte olimpo
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | okha
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | chietla
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | pokosnoye
# Processing Record 39 of Set 1 | kaisiadorys
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | simbahan
# Processing Record 42 of Set 1 | bonthe
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | bandarbeyla
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | tura
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | saint-francois
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | umm lajj
# Processing Record 5 of Set 2 | lakes entrance
# Processing Record 6 of Set 2 | nouadhibou
# Processing Record 7 of Set 2 | progreso
# Processing Record 8 of Set 2 | visby
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | road town
# Processing Record 11 of Set 2 | banjar
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | urengoy
# Processing Record 14 of Set 2 | komsomolskiy
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | tilichiki
# Processing Record 19 of Set 2 | sunrise manor
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | ried
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | kloulklubed
# Processing Record 26 of Set 2 | mitsamiouli
# Processing Record 27 of Set 2 | malmyzh
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | evensk
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | arman
# Processing Record 32 of Set 2 | mogadishu
# Processing Record 33 of Set 2 | avera
# Processing Record 34 of Set 2 | si sa ket
# Processing Record 35 of Set 2 | yakuplu
# Processing Record 36 of Set 2 | arlit
# Processing Record 37 of Set 2 | mecca
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | khasan
# Processing Record 40 of Set 2 | olafsvik
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | isla mujeres
# Processing Record 43 of Set 2 | severomuysk
# Processing Record 44 of Set 2 | cuiluan
# Processing Record 45 of Set 2 | gandia
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | baltiysk
# Processing Record 48 of Set 2 | mayo
# Processing Record 49 of Set 2 | gejiu
# Processing Record 50 of Set 2 | yulara
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | nueve de julio
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | paramonga
# Processing Record 5 of Set 3 | muisne
# Processing Record 6 of Set 3 | namie
# Processing Record 7 of Set 3 | honiara
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | ugoofaaru
# Processing Record 11 of Set 3 | los llanos de aridane
# Processing Record 12 of Set 3 | nybro
# Processing Record 13 of Set 3 | kununurra
# Processing Record 14 of Set 3 | gardenstown
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | chizhou
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | rio cuarto
# Processing Record 19 of Set 3 | atar
# Processing Record 20 of Set 3 | noyabrsk
# Processing Record 21 of Set 3 | kifri
# Processing Record 22 of Set 3 | novikovo
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | sept-iles
# Processing Record 25 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | deputatskiy
# Processing Record 29 of Set 3 | izvoarele sucevei
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | naryan-mar
# Processing Record 35 of Set 3 | baykit
# Processing Record 36 of Set 3 | campbell river
# Processing Record 37 of Set 3 | galle
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | vitim
# Processing Record 40 of Set 3 | namatanai
# Processing Record 41 of Set 3 | nuevo ideal
# Processing Record 42 of Set 3 | nova gradiska
# Processing Record 43 of Set 3 | hobart
# Processing Record 44 of Set 3 | kemijarvi
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | ekibastuz
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | bonavista
# Processing Record 1 of Set 4 | hovd
# Processing Record 2 of Set 4 | salzwedel
# Processing Record 3 of Set 4 | malacky
# Processing Record 4 of Set 4 | campina grande do sul
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | amalfi
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | port hedland
# Processing Record 9 of Set 4 | nikolayevka
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | bureya
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | kihei
# Processing Record 19 of Set 4 | lejanias
# Processing Record 20 of Set 4 | clermont
# Processing Record 21 of Set 4 | kirando
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | grand-lahou
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | rudnogorsk
# Processing Record 26 of Set 4 | bend
# Processing Record 27 of Set 4 | galesong
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | nabire
# Processing Record 31 of Set 4 | kidal
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | presidente franco
# Processing Record 34 of Set 4 | chernukha
# Processing Record 35 of Set 4 | port blair
# Processing Record 36 of Set 4 | denpasar
# Processing Record 37 of Set 4 | dera bugti
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | cascais
# Processing Record 40 of Set 4 | strezhevoy
# Processing Record 41 of Set 4 | suntar
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | darhan
# Processing Record 44 of Set 4 | comodoro rivadavia
# Processing Record 45 of Set 4 | preobrazheniye
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | burica
# City not found. Skipping...
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | kalabo
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | sawtell
# Processing Record 3 of Set 5 | acapulco
# Processing Record 4 of Set 5 | filadelfia
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | kutum
# Processing Record 7 of Set 5 | richards bay
# Processing Record 8 of Set 5 | codrington
# Processing Record 9 of Set 5 | imeni poliny osipenko
# Processing Record 10 of Set 5 | kawalu
# Processing Record 11 of Set 5 | bambanglipuro
# Processing Record 12 of Set 5 | dauriya
# Processing Record 13 of Set 5 | andenes
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | chimore
# Processing Record 18 of Set 5 | morondava
# Processing Record 19 of Set 5 | serpneve
# Processing Record 20 of Set 5 | hami
# Processing Record 21 of Set 5 | quatre cocos
# Processing Record 22 of Set 5 | stavern
# Processing Record 23 of Set 5 | placido de castro
# Processing Record 24 of Set 5 | zheleznogorsk-ilimskiy
# Processing Record 25 of Set 5 | ambatondrazaka
# Processing Record 26 of Set 5 | chapais
# Processing Record 27 of Set 5 | chaihe
# Processing Record 28 of Set 5 | mizan teferi
# Processing Record 29 of Set 5 | inhambane
# Processing Record 30 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 5 | college
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | flin flon
# Processing Record 34 of Set 5 | kahului
# Processing Record 35 of Set 5 | gizo
# Processing Record 36 of Set 5 | dasoguz
# Processing Record 37 of Set 5 | paramirim
# Processing Record 38 of Set 5 | geraldton
# Processing Record 39 of Set 5 | khatanga
# Processing Record 40 of Set 5 | ust-ilimsk
# Processing Record 41 of Set 5 | jiayuguan
# Processing Record 42 of Set 5 | faanui
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 5 | aswan
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | mata
# Processing Record 49 of Set 5 | namibe
# Processing Record 50 of Set 5 | labuhan
# Processing Record 1 of Set 6 | skibotn
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | collie
# Processing Record 4 of Set 6 | ciudad del maiz
# Processing Record 5 of Set 6 | hit
# Processing Record 6 of Set 6 | malakal
# Processing Record 7 of Set 6 | manati
# Processing Record 8 of Set 6 | west plains
# Processing Record 9 of Set 6 | chernyshevskiy
# Processing Record 10 of Set 6 | victoria
# Processing Record 11 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | grand gaube
# Processing Record 15 of Set 6 | chumikan
# Processing Record 16 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | calabozo
# Processing Record 21 of Set 6 | maracacume
# Processing Record 22 of Set 6 | omutinskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | whitehorse
# Processing Record 25 of Set 6 | auburn
# Processing Record 26 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 6 | benghazi
# Processing Record 28 of Set 6 | utena
# Processing Record 29 of Set 6 | holetown
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | makakilo city
# Processing Record 32 of Set 6 | sorland
# Processing Record 33 of Set 6 | ixtapa
# Processing Record 34 of Set 6 | mugango
# Processing Record 35 of Set 6 | veraval
# Processing Record 36 of Set 6 | cuamba
# Processing Record 37 of Set 6 | porbandar
# Processing Record 38 of Set 6 | vila
# Processing Record 39 of Set 6 | carnarvon
# Processing Record 40 of Set 6 | erzin
# Processing Record 41 of Set 6 | raudeberg
# Processing Record 42 of Set 6 | yashkul
# Processing Record 43 of Set 6 | albanel
# Processing Record 44 of Set 6 | homer
# Processing Record 45 of Set 6 | gorontalo
# Processing Record 46 of Set 6 | kudymkar
# Processing Record 47 of Set 6 | swan hill
# Processing Record 48 of Set 6 | san carlos de bariloche
# Processing Record 49 of Set 6 | asau
# Processing Record 50 of Set 6 | marshall
# Processing Record 1 of Set 7 | yurino
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | huancavelica
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | gasa
# Processing Record 6 of Set 7 | ipu
# Processing Record 7 of Set 7 | shagonar
# Processing Record 8 of Set 7 | kirakira
# Processing Record 9 of Set 7 | shirokiy
# Processing Record 10 of Set 7 | isla vista
# Processing Record 11 of Set 7 | ravar
# Processing Record 12 of Set 7 | maumere
# Processing Record 13 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 7 | araouane
# Processing Record 15 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 7 | lao cai
# Processing Record 17 of Set 7 | korla
# Processing Record 18 of Set 7 | baoding
# Processing Record 19 of Set 7 | sudislavl
# Processing Record 20 of Set 7 | sa kaeo
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | kaitangata
# Processing Record 23 of Set 7 | ribeira grande
# Processing Record 24 of Set 7 | babynino
# Processing Record 25 of Set 7 | adrar
# Processing Record 26 of Set 7 | yokadouma
# Processing Record 27 of Set 7 | itaituba
# Processing Record 28 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 7 | savannah bight
# Processing Record 30 of Set 7 | teghra
# Processing Record 31 of Set 7 | severo-kurilsk
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | rundu
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | dromolaxia
# Processing Record 37 of Set 7 | waipawa
# Processing Record 38 of Set 7 | morehead
# Processing Record 39 of Set 7 | beloha
# Processing Record 40 of Set 7 | tutoia
# Processing Record 41 of Set 7 | nerja
# Processing Record 42 of Set 7 | kalmunai
# Processing Record 43 of Set 7 | putol
# Processing Record 44 of Set 7 | dzaoudzi
# Processing Record 45 of Set 7 | saint-augustin
# Processing Record 46 of Set 7 | mikhaylovka
# Processing Record 47 of Set 7 | chuguyevka
# Processing Record 48 of Set 7 | aquiraz
# Processing Record 49 of Set 7 | fitii
# Processing Record 50 of Set 7 | antsohihy
# Processing Record 1 of Set 8 | verkhoshizhemye
# Processing Record 2 of Set 8 | tasiilaq
# Processing Record 3 of Set 8 | dingle
# Processing Record 4 of Set 8 | pevek
# Processing Record 5 of Set 8 | tarragona
# Processing Record 6 of Set 8 | clyde river
# Processing Record 7 of Set 8 | naze
# Processing Record 8 of Set 8 | mizdah
# Processing Record 9 of Set 8 | tiznit
# Processing Record 10 of Set 8 | macusani
# Processing Record 11 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | havelock
# Processing Record 14 of Set 8 | tooele
# Processing Record 15 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 16 of Set 8 | roald
# Processing Record 17 of Set 8 | sabha
# Processing Record 18 of Set 8 | nitra
# Processing Record 19 of Set 8 | quzhou
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | clyde
# Processing Record 24 of Set 8 | troitsko-pechorsk
# Processing Record 25 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 26 of Set 8 | broome
# Processing Record 27 of Set 8 | upernavik
# Processing Record 28 of Set 8 | salalah
# Processing Record 29 of Set 8 | toora-khem
# Processing Record 30 of Set 8 | moratuwa
# Processing Record 31 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 8 | huangmei
# Processing Record 35 of Set 8 | xining
# Processing Record 36 of Set 8 | alofi
# Processing Record 37 of Set 8 | popondetta
# Processing Record 38 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 8 | malumfashi
# Processing Record 40 of Set 8 | chupa
# Processing Record 41 of Set 8 | yinchuan
# Processing Record 42 of Set 8 | firovo
# Processing Record 43 of Set 8 | ta khmau
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | kanniyakumari
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | jijiga
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | hualmay
# Processing Record 50 of Set 8 | jacksonville beach
# Processing Record 1 of Set 9 | jumla
# Processing Record 2 of Set 9 | mindelo
# Processing Record 3 of Set 9 | san patricio
# Processing Record 4 of Set 9 | kushima
# Processing Record 5 of Set 9 | le portel
# Processing Record 6 of Set 9 | olinda
# Processing Record 7 of Set 9 | shingu
# Processing Record 8 of Set 9 | carutapera
# Processing Record 9 of Set 9 | praia da vitoria
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | zhigansk
# Processing Record 12 of Set 9 | srednekolymsk
# Processing Record 13 of Set 9 | chapleau
# Processing Record 14 of Set 9 | tinskoy
# Processing Record 15 of Set 9 | yeppoon
# Processing Record 16 of Set 9 | beringovskiy
# Processing Record 17 of Set 9 | mana
# Processing Record 18 of Set 9 | pontianak
# Processing Record 19 of Set 9 | pervomayskoye
# Processing Record 20 of Set 9 | borogontsy
# Processing Record 21 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 9 | yerbogachen
# Processing Record 23 of Set 9 | lingyuan
# Processing Record 24 of Set 9 | seminole
# Processing Record 25 of Set 9 | charters towers
# Processing Record 26 of Set 9 | luanda
# Processing Record 27 of Set 9 | diego de almagro
# Processing Record 28 of Set 9 | pahrump
# Processing Record 29 of Set 9 | bonnyville
# Processing Record 30 of Set 9 | salina
# Processing Record 31 of Set 9 | oussouye
# Processing Record 32 of Set 9 | canada
# Processing Record 33 of Set 9 | creel
# Processing Record 34 of Set 9 | te anau
# Processing Record 35 of Set 9 | pumiao
# Processing Record 36 of Set 9 | meulaboh
# Processing Record 37 of Set 9 | nelson bay
# Processing Record 38 of Set 9 | bereda
# Processing Record 39 of Set 9 | karratha
# Processing Record 40 of Set 9 | freising
# Processing Record 41 of Set 9 | port hardy
# Processing Record 42 of Set 9 | saryg-sep
# Processing Record 43 of Set 9 | the valley
# Processing Record 44 of Set 9 | lebork
# Processing Record 45 of Set 9 | kaeo
# Processing Record 46 of Set 9 | jiazi
# Processing Record 47 of Set 9 | pangnirtung
# Processing Record 48 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 9 | riyadh
# Processing Record 50 of Set 9 | kingaroy
# Processing Record 1 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 10 | maragogi
# Processing Record 3 of Set 10 | port keats
# Processing Record 4 of Set 10 | altay
# Processing Record 5 of Set 10 | larsnes
# Processing Record 6 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 10 | kilindoni
# Processing Record 8 of Set 10 | santa cruz
# Processing Record 9 of Set 10 | muros
# Processing Record 10 of Set 10 | bray
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | constantine
# Processing Record 13 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 10 | khash
# Processing Record 15 of Set 10 | bonfim
# Processing Record 16 of Set 10 | cidreira
# Processing Record 17 of Set 10 | nizhniy tsasuchey
# Processing Record 18 of Set 10 | westport
# Processing Record 19 of Set 10 | santander jimenez
# Processing Record 20 of Set 10 | ilorin
# Processing Record 21 of Set 10 | gimli
# Processing Record 22 of Set 10 | maldonado
# Processing Record 23 of Set 10 | fuquay-varina
# Processing Record 24 of Set 10 | dukat
# Processing Record 25 of Set 10 | madingou
# Processing Record 26 of Set 10 | bourges
# Processing Record 27 of Set 10 | dobson
# Processing Record 28 of Set 10 | boca do acre
# Processing Record 29 of Set 10 | trelleborg
# Processing Record 30 of Set 10 | rulenge
# Processing Record 31 of Set 10 | kudahuvadhoo
# Processing Record 32 of Set 10 | pochutla
# Processing Record 33 of Set 10 | hanchuan
# Processing Record 34 of Set 10 | yeniseysk
# Processing Record 35 of Set 10 | saldanha
# Processing Record 36 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 10 | makat
# Processing Record 38 of Set 10 | pangkalanbuun
# Processing Record 39 of Set 10 | abashiri
# Processing Record 40 of Set 10 | grafton
# Processing Record 41 of Set 10 | brokopondo
# Processing Record 42 of Set 10 | vila velha
# Processing Record 43 of Set 10 | sao miguel
# Processing Record 44 of Set 10 | beyneu
# Processing Record 45 of Set 10 | ambikapur
# Processing Record 46 of Set 10 | celestun
# Processing Record 47 of Set 10 | wanlaweyn
# Processing Record 48 of Set 10 | fare
# Processing Record 49 of Set 10 | puerto madryn
# Processing Record 50 of Set 10 | ambulu
# Processing Record 1 of Set 11 | manzanillo
# Processing Record 2 of Set 11 | solnechnyy
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | eslov
# Processing Record 5 of Set 11 | broken hill
# Processing Record 6 of Set 11 | manono
# Processing Record 7 of Set 11 | saint-georges
# Processing Record 8 of Set 11 | gat
# Processing Record 9 of Set 11 | lorengau
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | hamilton
# Processing Record 12 of Set 11 | sunyani
# Processing Record 13 of Set 11 | havoysund
# Processing Record 14 of Set 11 | strasice
# Processing Record 15 of Set 11 | ust-nera
# Processing Record 16 of Set 11 | trelew
# Processing Record 17 of Set 11 | biltine
# Processing Record 18 of Set 11 | verkhnevilyuysk
# Processing Record 19 of Set 11 | pudozh
# Processing Record 20 of Set 11 | ucluelet
# Processing Record 21 of Set 11 | johnstown
# Processing Record 22 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 11 | aden
# Processing Record 26 of Set 11 | ishigaki
# Processing Record 27 of Set 11 | iskateley
# Processing Record 28 of Set 11 | cannes
# Processing Record 29 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | santiago
# Processing Record 31 of Set 11 | lieksa
# Processing Record 32 of Set 11 | hermiston
# Processing Record 33 of Set 11 | qidong
# Processing Record 34 of Set 11 | vakhtan
# Processing Record 35 of Set 11 | lasa
# Processing Record 36 of Set 11 | aykhal
# Processing Record 37 of Set 11 | sakakah
# Processing Record 38 of Set 11 | sibolga
# Processing Record 39 of Set 11 | waharoa
# Processing Record 40 of Set 11 | praia
# Processing Record 41 of Set 11 | dzhebariki-khaya
# Processing Record 42 of Set 11 | glasgow
# Processing Record 43 of Set 11 | buchanan
# Processing Record 44 of Set 11 | belyy yar
# Processing Record 45 of Set 11 | prado
# Processing Record 46 of Set 11 | songjianghe
# Processing Record 47 of Set 11 | muborak
# Processing Record 48 of Set 11 | mnogovershinnyy
# Processing Record 49 of Set 11 | tautira
# Processing Record 50 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 12 | jalu
# Processing Record 2 of Set 12 | rovaniemi
# Processing Record 3 of Set 12 | pulaski
# Processing Record 4 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 5 of Set 12 | ylivieska
# Processing Record 6 of Set 12 | port-gentil
# Processing Record 7 of Set 12 | lisakovsk
# Processing Record 8 of Set 12 | balykshi
# Processing Record 9 of Set 12 | jacksonville
# Processing Record 10 of Set 12 | odweyne
# Processing Record 11 of Set 12 | lompoc
# Processing Record 12 of Set 12 | atambua
# Processing Record 13 of Set 12 | deniliquin
# Processing Record 14 of Set 12 | taoudenni
# Processing Record 15 of Set 12 | port lincoln
# Processing Record 16 of Set 12 | ust-tsilma
# Processing Record 17 of Set 12 | alexandria
# Processing Record 18 of Set 12 | ilulissat
# Processing Record 19 of Set 12 | igarassu
# Processing Record 20 of Set 12 | miedzychod
# Processing Record 21 of Set 12 | garissa
# Processing Record 22 of Set 12 | amuntai
# Processing Record 23 of Set 12 | dongying
# Processing Record 24 of Set 12 | tocopilla
# Processing Record 25 of Set 12 | stephenville
# Processing Record 26 of Set 12 | severnoye
# Processing Record 27 of Set 12 | ambanja
# Processing Record 28 of Set 12 | kitui
# Processing Record 29 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 30 of Set 12 | abha
# Processing Record 31 of Set 12 | sandovo
# Processing Record 32 of Set 12 | touros
# Processing Record 33 of Set 12 | cherat
# Processing Record 34 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 12 | mae hong son
# Processing Record 36 of Set 12 | daru
# Processing Record 37 of Set 12 | fowa
# Processing Record 38 of Set 12 | mareeba
# Processing Record 39 of Set 12 | san cristobal
# Processing Record 40 of Set 12 | dubti
# Processing Record 41 of Set 12 | vestmannaeyjar
# Processing Record 42 of Set 12 | pyapon
# Processing Record 43 of Set 12 | inirida
# Processing Record 44 of Set 12 | pisco
# Processing Record 45 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 12 | gondar
# Processing Record 47 of Set 12 | tigil
# Processing Record 48 of Set 12 | chandbali
# Processing Record 49 of Set 12 | hofn
# Processing Record 50 of Set 12 | tual
# Processing Record 1 of Set 13 | marechal candido rondon
# Processing Record 2 of Set 13 | tatawin
# Processing Record 3 of Set 13 | lengshuijiang
# Processing Record 4 of Set 13 | walvis bay
# Processing Record 5 of Set 13 | lubango
# Processing Record 6 of Set 13 | pitimbu
# Processing Record 7 of Set 13 | brae
# Processing Record 8 of Set 13 | banjarmasin
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | takoradi
# Processing Record 12 of Set 13 | senneterre
# Processing Record 13 of Set 13 | lichinga
# Processing Record 14 of Set 13 | nobres
# Processing Record 15 of Set 13 | cap malheureux
# Processing Record 16 of Set 13 | san vicente
# Processing Record 17 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 13 | sibu
# Processing Record 20 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 13 | isangel
# Processing Record 22 of Set 13 | xinqing
# Processing Record 23 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 13 | pionerskiy
# Processing Record 25 of Set 13 | teguise
# Processing Record 26 of Set 13 | butterworth
# Processing Record 27 of Set 13 | samarai
# Processing Record 28 of Set 13 | iquitos
# Processing Record 29 of Set 13 | nyrob
# Processing Record 30 of Set 13 | hearst
# Processing Record 31 of Set 13 | marystown
# Processing Record 32 of Set 13 | maple creek
# Processing Record 33 of Set 13 | dwarka
# Processing Record 34 of Set 13 | mujiayingzi
# Processing Record 35 of Set 13 | zapolyarnyy
# Processing Record 36 of Set 13 | baghdad
# Processing Record 37 of Set 13 | margate
# Processing Record 38 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 13 | berlevag
# Processing Record 40 of Set 13 | storforshei
# Processing Record 41 of Set 13 | venkatagiri
# Processing Record 42 of Set 13 | umm kaddadah
# Processing Record 43 of Set 13 | santa marta
# Processing Record 44 of Set 13 | savonlinna
# Processing Record 45 of Set 13 | anadyr
# Processing Record 46 of Set 13 | guiratinga
# Processing Record 47 of Set 13 | hilton head island
# Processing Record 48 of Set 13 | san rafael
# Processing Record 49 of Set 13 | millbrook
# Processing Record 50 of Set 13 | marsh harbour
# Processing Record 1 of Set 14 | paita
# Processing Record 2 of Set 14 | merauke
# Processing Record 3 of Set 14 | okhotsk
# Processing Record 4 of Set 14 | berbera
# Processing Record 5 of Set 14 | muroto
# Processing Record 6 of Set 14 | ziro
# Processing Record 7 of Set 14 | nizhnevartovsk
# Processing Record 8 of Set 14 | ilabaya
# Processing Record 9 of Set 14 | cuenca
# Processing Record 10 of Set 14 | onalaska
# Processing Record 11 of Set 14 | kakching
# Processing Record 12 of Set 14 | itarema
# Processing Record 13 of Set 14 | tezu
# Processing Record 14 of Set 14 | taltal
# Processing Record 15 of Set 14 | puerto colombia
# Processing Record 16 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 14 | wewak
# Processing Record 18 of Set 14 | kedgwick
# Processing Record 19 of Set 14 | tornio
# Processing Record 20 of Set 14 | ketchikan
# Processing Record 21 of Set 14 | byron bay
# Processing Record 22 of Set 14 | kaura namoda
# Processing Record 23 of Set 14 | viedma
# Processing Record 24 of Set 14 | andros town
# Processing Record 25 of Set 14 | griffith
# Processing Record 26 of Set 14 | zhangjiakou
# Processing Record 27 of Set 14 | la ronge
# Processing Record 28 of Set 14 | necochea
# Processing Record 29 of Set 14 | huarmey
# Processing Record 30 of Set 14 | kikwit
# Processing Record 31 of Set 14 | sao joao do paraiso
# Processing Record 32 of Set 14 | opuwo
# Processing Record 33 of Set 14 | arklow
# Processing Record 34 of Set 14 | marawi
# Processing Record 35 of Set 14 | sampit
# Processing Record 36 of Set 14 | dryden
# Processing Record 37 of Set 14 | maamba
# Processing Record 38 of Set 14 | dire dawa
# Processing Record 39 of Set 14 | berdigestyakh
# Processing Record 40 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 41 of Set 14 | lazurne
# Processing Record 42 of Set 14 | conakry
# Processing Record 43 of Set 14 | chatsu
# City not found. Skipping...
# Processing Record 44 of Set 14 | sterling
# Processing Record 45 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 46 of Set 14 | bairiki
# Processing Record 47 of Set 14 | touba
# Processing Record 48 of Set 14 | iquique
# Processing Record 49 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 14 | leningradskiy
# Processing Record 1 of Set 15 | katobu
# Processing Record 2 of Set 15 | lucapa
# Processing Record 3 of Set 15 | burgersdorp
# Processing Record 4 of Set 15 | hermosillo
# Processing Record 5 of Set 15 | ambon
# Processing Record 6 of Set 15 | bahia blanca
# Processing Record 7 of Set 15 | humaita
# Processing Record 8 of Set 15 | krasnoselkup
# Processing Record 9 of Set 15 | ulladulla
# Processing Record 10 of Set 15 | bjornevatn
# Processing Record 11 of Set 15 | faya
# Processing Record 12 of Set 15 | kapit
# Processing Record 13 of Set 15 | sug-aksy
# City not found. Skipping...
# Processing Record 14 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 15 of Set 15 | nalut
# Processing Record 16 of Set 15 | wajima
# Processing Record 17 of Set 15 | hailar
# Processing Record 18 of Set 15 | churapcha
# Processing Record 19 of Set 15 | ashcroft
# Processing Record 20 of Set 15 | vilhena
# Processing Record 21 of Set 15 | chapayevka
# Processing Record 22 of Set 15 | quchan
# Processing Record 23 of Set 15 | portland
# Processing Record 24 of Set 15 | paamiut
# Processing Record 25 of Set 15 | port macquarie
# Processing Record 26 of Set 15 | sinop
# Processing Record 27 of Set 15 | kavaratti
# Processing Record 28 of Set 15 | svetlyy
# Processing Record 29 of Set 15 | ewa beach
# Processing Record 30 of Set 15 | ridgecrest
# Processing Record 31 of Set 15 | nago
# Processing Record 32 of Set 15 | cervo
# Processing Record 33 of Set 15 | mormugao
# Processing Record 34 of Set 15 | son tay
# Processing Record 35 of Set 15 | muleba
# Processing Record 36 of Set 15 | loubomo
# Processing Record 37 of Set 15 | alekseyevka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0        New Norfolk -42.7826  147.0587     63.91        56          20
# 1         San Martin -33.0810  -68.4681     68.54        49          40
# 2             Dikson  73.5069   80.5464     30.38        85         100
# 3              Vaini -21.2000 -175.2000     71.76        83          75
# 4  Nerchinskiy Zavod  51.3088  119.6100     49.10        58         100
# 5          Cape Town -33.9258   18.4232     61.38        83          75
# 6              Vardo  70.3705   31.1107     51.78        62           0
# 7              Tabou   4.4230   -7.3528     80.56        87         100
# 8       Puerto Ayora  -0.7393  -90.3518     85.96        85          16
# 9       Ponta Do Sol  32.6667  -17.1000     68.72        72          54
#
#    Wind_Speed Country   Weather_Description
# 0        3.00      AU         moderate rain
# 1        5.93      AR      scattered clouds
# 2       18.14      RU       overcast clouds
# 3        4.61      TO         broken clouds
# 4        7.56      RU  heavy intensity rain
# 5       14.97      ZA            light rain
# 6       19.57      NO             clear sky
# 7        9.06      CI            light rain
# 8        7.00      EC            few clouds
# 9        4.70      PT         broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max_Temp', 'Humidity', 'Cloudiness',
#        'Wind_Speed', 'Country', 'Weather_Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ['City', 'Country', 'Lat', 'Lng', 'Max_Temp', 'Humidity', 'Cloudiness', 'Wind_Speed', 'Weather_Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#                 City Country      Lat       Lng  Max_Temp  Humidity  \
# 0        New Norfolk      AU -42.7826  147.0587     63.91        56
# 1         San Martin      AR -33.0810  -68.4681     68.54        49
# 2             Dikson      RU  73.5069   80.5464     30.38        85
# 3              Vaini      TO -21.2000 -175.2000     71.76        83
# 4  Nerchinskiy Zavod      RU  51.3088  119.6100     49.10        58
#
#    Cloudiness  Wind_Speed   Weather_Description
# 0          20        3.00         moderate rain
# 1          40        5.93      scattered clouds
# 2         100       18.14       overcast clouds
# 3          75        4.61         broken clouds
# 4         100        7.56  heavy intensity rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max_Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind_Speed             float64
# Weather_Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file,index=False)
